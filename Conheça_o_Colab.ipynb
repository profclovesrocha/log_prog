# %% [markdown]
# <a href="https://colab.research.google.com/github/profclovesrocha/log_prog/blob/main/Conhe%C3%A7a_o_Colab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# UNINASSAU PAULISTA
# DOCENTE: PROF. CLOVES ROCHA
# ESTUDANTE: LUCAS GABRIEL / GABRIEL HENRIQUE
# DISCIPLINA: LOGICA DE PROGRAMAÇÃO

A = 10
B = 20
C = (A+B)
print(C)
# Out:
# 30

# %%
a = 10
b = 12
soma = a + b
media = (a + b) /2
print("soma:" , soma)
print("media:" , media)
# Out:
# soma: 22
# media: 11.0

# %%
n = 7
resto = n % 2
quad = n ** 2
print("resto da divisao por 2:" , resto)
print("quadrado:" , quad)
# Out:
# resto da divisao por 2: 1
# quadrado: 49
