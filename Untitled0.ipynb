# %% [markdown]
# <a href="https://colab.research.google.com/github/profclovesrocha/log_prog/blob/main/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# @title Texto de título padrão
# Uninassau paulista
#Docente: Professor Cloves
# Estudante: Rafael Mpises Ferreira Santiago
# Lógica de Programação

A = 10
B = 20
C = (A+B)
print(C)
# Out:
# 30

# %%
a = 10
b = 3
soma = a+b
media = (a+b)  / 2
print('Soma:', soma)
print('Media:', media)
# Out:
# Soma: 13
# Media: 6.5

# %%
# Exemplo 2 - usando exponiciação
n = 7
resto = n % 2
quad = n ** 2
print( 'Resto da divisão por 2:' , resto)
print( 'quadrado:', quad)
# Out:
# Resto da divisão por 2: 1
# quadrado: 49
