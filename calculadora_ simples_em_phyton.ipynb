# %% [markdown]
# <a href="https://colab.research.google.com/github/profclovesrocha/log_prog/blob/main/calculadora_%20simples_em_phyton.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# UNINASSAU PAULISTA
# DOCENTE: PROF. CLOVES ROCHA
# ESTUDANTE: ARTHUR JOSÉ ARRUDA PESSOA BRANDÃO
# DISCIPLINA: LÓGICA DE PROGRAMAÇÃO

A = 15
B = 23
C = (A+B)
print(C)
# Out:
# 38

# %%
# Exemplo 1 - atribuição e operação

a = 45
b = 12
soma = a + b
media = (a + b) / 2
print( 'Soma de a + b é:' , soma)
print('A Média é:' , media )
# Out:
# Soma 22
# Média 11.0

# %%
# Exemplo 2 - usando módulo e exponenciação:
n = 7
resto = n % 2
quad = n ** 2
print('Resto da divisão É:' , resto)
print('Quadrado:', quad)
# Out:
# Resto da divisão É: 1
# Quadrado: 49
